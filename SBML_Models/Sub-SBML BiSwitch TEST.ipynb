# %%
# Imports
#from genelet import*
from subsbml import System, createNewSubsystem, createSubsystem, combineSystems
import numpy as np
import pylab as plt


from bokeh.layouts import row
from bokeh.io import export_png

import warnings
import bokeh.io
import bokeh.plotting

# %% [markdown]
# # Bistable Switch Recreate

# %%
ss1 = createSubsystem ("BiSwitch_CRN.xml")


Core1_id = ss1.getSpeciesByName('complex_Core1_ON').getId()
Core1R_id = ss1.getSpeciesByName('Core1_OFF').getId()
Core2_id = ss1.getSpeciesByName('complex_Core2_ON').getId()
Core2R_id = ss1.getSpeciesByName('Core2_OFF').getId()
dA2_rR2 = ss1.getSpeciesByName("complex_Core1_AI").getId()


# Set species amount
ss1.setSpeciesAmount('Core1_OFF', 1.2)
ss1.setSpeciesAmount('Core2_OFF', 0.99)
ss1.setSpeciesAmount('dna_dA2', 1.2)
ss1.setSpeciesAmount('dna_dA1', 1.2)
ss1.setSpeciesAmount('protein_RNAseH', 0.0044)
ss1.setSpeciesAmount('protein_RNAP', 0.030)
# Out:
# True

# %%
# Simulate with Bioscrape
timepoints = np.linspace(0, 28800, 1000)
results,_ = ss1.simulateWithBioscrape(timepoints)
timepoints = timepoints/3600

# For label convenience
x = 'Time (seconds)'
y = 'Concentration (uM)'

# Core 1 & Core 2
bokeh.io.output_notebook()
a = bokeh.plotting.figure(plot_width=400, plot_height=300, x_axis_label = x, y_axis_label = y)
a.circle(timepoints, results[Core1_id], legend_label = "ON Core 1" , color = "blue")
a.circle(timepoints, results[Core2_id], legend_label = "ON Core 2", color = "red")
a.legend.click_policy="hide"
a.legend.location="bottom_right"


bokeh.io.show(row(a))
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Jeremiah\anaconda3\lib\site-packages\bioscrape\sbmlutil.py:208: UserWarning: Compartments, UnitDefintions, Events, and some other SBML model components are not recognized by bioscrape. Refer to the bioscrape wiki for more information.
#   warnings.warn('Compartments, UnitDefintions, Events, and some other SBML model components are not recognized by bioscrape. ' +
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f6e8aeec-4f98-44a1-b074-9d6fb470224c" data-root-id="1063"></div>

# %% [raw]
# from bioscrape.sbmlutil import import_sbml
# M = import_sbml('Bistable_Switch/BiSwitch_CRN.xml')
# M.write_bioscrape_xml('bioscrape_file.xml')
